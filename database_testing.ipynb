# %%
import sqlite3
import pandas as pd

# %%
con = sqlite3.connect("./RAD.sqlite3")
game_xml = pd.read_sql("SELECT * FROM RAW_DATA_NBA_GAMES where DATA not in ('<h1>Developer Over Rate</h1>', '<h1>Developer Over Qps</h1>')", con=con)
con.close()

game_xml.shape
# Out:
# (741, 2)

# %%
con = sqlite3.connect("./RAD.sqlite3")
data = pd.read_sql(f"""
                SELECT DISTINCT * 
                FROM RAW_DATA_NBA_GAMES 
                WHERE DATA not in ('<h1>Developer Over Rate</h1>', '<h1>Developer Over Qps</h1>')
                """, con=con
)
con.close()

xml_data = data["DATA"].values.tolist()
xml_cont = xml_data[2].strip()

with open("./xml_play_data.xml", 'w', encoding='utf-8') as new_file:
    new_file.write(xml_cont)

# %%
game_xml.to_excel("xml_game_data.xlsx", index=False)

# %%
con = sqlite3.connect("./RAD.sqlite3")
game_schedules = pd.read_sql("""SELECT * FROM 
                             NBA_GAME_DETAILS_CUR WHERE DATE(GAME_DATE) = '2024-02-13'
                             ORDER BY GAME_DATE DESC
                             """, con=con)
con.close()

game_ids = game_schedules["GAME_ID"].to_list()

# game_ids

# %%
game_schedules.head(20)
# Out:
#                                 GAME_ID            HOME_TEAM  \
# 0  9f12f954-1022-4066-b51c-b9bff77a312d          LA Clippers
# 1  2a2b4da6-dccf-4304-8855-956a631bcb1b            Utah Jazz
# 2  da378f9d-656e-4f5a-aadc-ea2aa9e7637f     Dallas Mavericks
# 3  4b94c315-8dd9-4c82-a7d9-e1e7aa86c8bc      Milwaukee Bucks
# 4  b5a8775d-4e3c-47b1-b165-1aaa159b2906    Memphis Grizzlies
# 5  de905cb3-20ad-4ae1-9505-bc21e621f18c      Houston Rockets
# 6  7d824a3c-949a-4fc1-a8e3-79b03b9e8fda        Atlanta Hawks
# 7  f8ee3dd8-349c-4f7e-b332-76c8d07d440f      Toronto Raptors
# 8  7d8766bd-ec14-44e7-b577-84a03c8c6b62    Charlotte Hornets
# 9  da341cd4-f387-471a-bc33-33b1262468dc  Cleveland Cavaliers
#
#                 AWAY_TEAM HOME_ALIAS AWAY_ALIAS             GAME_DATE  \
# 0  Minnesota Timberwolves        LAC        MIN  2024-02-13T03:30:00Z
# 1   Golden State Warriors        UTA        GSW  2024-02-13T02:00:00Z
# 2      Washington Wizards        DAL        WAS  2024-02-13T01:30:00Z
# 3          Denver Nuggets        MIL        DEN  2024-02-13T01:00:00Z
# 4    New Orleans Pelicans        MEM        NOP  2024-02-13T01:00:00Z
# 5         New York Knicks        HOU        NYK  2024-02-13T01:00:00Z
# 6           Chicago Bulls        ATL        CHI  2024-02-13T00:30:00Z
# 7       San Antonio Spurs        TOR        SAS  2024-02-13T00:30:00Z
# 8          Indiana Pacers        CHA        IND  2024-02-13T00:00:00Z
# 9      Philadelphia 76ers        CLE        PHI  2024-02-13T00:00:00Z
#
#                    VENUE_NAME GAME_STATUS HOME_POINTS AWAY_POINTS
# 0            Crypto.com Arena   scheduled        None        None
# 1                Delta Center   scheduled        None        None
# 2    American Airlines Center   scheduled        None        None
# 3                Fiserv Forum   scheduled        None        None
# 4                  FedExForum   scheduled        None        None
# 5               Toyota Center   scheduled        None        None
# 6            State Farm Arena   scheduled        None        None
# 7            Scotiabank Arena   scheduled        None        None
# 8             Spectrum Center   scheduled        None        None
# 9  Rocket Mortgage Fieldhouse   scheduled        None        None

# %%
game_schedules.tail()
# Out:
#                                  GAME_ID          HOME_TEAM  \
# 23  914148aa-699c-4931-aac3-f1b7ee6c26c3  Memphis Grizzlies
# 24  e66bbb9e-ce01-449c-bf45-46bea71fe3f1      Brooklyn Nets
# 25  ec46ada7-401a-4256-9505-6e7c3d94d18d    New York Knicks
# 26  1788e97c-26c5-4fa1-94c5-08f2e7cdff50     Indiana Pacers
# 27  a4bc8099-1d93-4637-a9d1-0f894fead33d      Orlando Magic
#
#                 AWAY_TEAM HOME_ALIAS AWAY_ALIAS             GAME_DATE  \
# 23          Chicago Bulls        MEM        CHI  2024-02-09T01:00:00Z
# 24    Cleveland Cavaliers        BKN        CLE  2024-02-09T00:30:00Z
# 25       Dallas Mavericks        NYK        DAL  2024-02-09T00:30:00Z
# 26  Golden State Warriors        IND        GSW  2024-02-09T00:00:00Z
# 27      San Antonio Spurs        ORL        SAS  2024-02-09T00:00:00Z
#
#                VENUE_NAME GAME_STATUS HOME_POINTS AWAY_POINTS
# 23             FedExForum   scheduled        None        None
# 24        Barclays Center   scheduled        None        None
# 25  Madison Square Garden   scheduled        None        None
# 26  Gainbridge Fieldhouse   scheduled        None        None
# 27             Kia Center   scheduled        None        None

# %%
len_game_ids = len(game_ids)

game_ids[len_game_ids - 1]
# Out:
# 'a4bc8099-1d93-4637-a9d1-0f894fead33d'

# %%
len_game_ids
# Out:
# 249

# %%
# Altering Database

import psycopg2

conn = psycopg2.connect(
    dbname="RAD_DFS",
    user="postgres",
    password="Tigers11",
    host="localhost",
    port="5432"
)

# Create a cursor object
cur = conn.cursor()

# SQL statement to alter the column data type
alter_query = """ALTER TABLE public."OVERTIME_DETAILS_CURR" ALTER COLUMN inseason_tournament TYPE VARCHAR;"""

# Execute the ALTER TABLE statement
cur.execute(alter_query)

# Commit the transaction
conn.commit()

# Close the cursor and connection
cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# /Users/jorge/Documents/Documents - Jorge’s MacBook Pro/dev/python/data-sanitation/nba/database_testing.ipynb Cell 10 line <cell line: 20>()
#      <a href='vscode-notebook-cell:/Users/jorge/Documents/Documents%20-%20Jorge%E2%80%99s%20MacBook%20Pro/dev/python/data-sanitation/nba/database_testing.ipynb#X12sZmlsZQ%3D%3D?line=16'>17</a> alter_query = """ALTER TABLE public."GAME_DETAILS_CURR" ALTER COLUMN inseason_tournament TYPE VARCHAR;"""
#      <a href='vscode-notebook-cell:/Users/jorge/Documents/Documents%20-%20Jorge%E2%80%99s%20MacBook%20Pro/dev/python/data-sanitation/nba/database_testing.ipynb#X12sZmlsZQ%3D%3D?line=18'>19</a> # Execute the ALTER TABLE statement
# ---> <a href='vscode-notebook-cell:/Users/jorge/Documents/Documents%20-%20Jorge%E2%80%99s%20MacBook%20Pro/dev/python/data-sanitation/nba/database_testing.ipynb#X12sZmlsZQ%3D%3D?line=19'>20</a> cur.execute(alter_query)
#      <a href='vscode-notebook-cell:/Users/jorge/Documents/Documents%20-%20Jorge%E2%80%99s%20MacBook%20Pro/dev/python/data-sanitation/nba/database_testing.ipynb#X12sZmlsZQ%3D%3D?line=21'>22</a> # Commit the transaction
#      <a href='vscode-notebook-cell:/Users/jorge/Documents/Documents%20-%20Jorge%E2%80%99s%20MacBook%20Pro/dev/python/data-sanitation/nba/database_testing.ipynb#X12sZmlsZQ%3D%3D?line=22'>23</a> conn.commit()
#
# UndefinedColumn: column "inseason_tournament" of relation "GAME_DETAILS_CURR" does not exist

# %%
# Altering Database
# last alter -- Create OVERTIME_DETAILS_CURR
# As of 2/16/24

import psycopg2

conn = psycopg2.connect(
    dbname="RAD_DFS",
    user="postgres",
    password="Tigers11",
    host="localhost",
    port="5432"
)

# Column list
col_list = ['clock', 'updated', 'wall_clock', 'sequence', 'home_points', 'away_points', 'clock_decimal'
            , 'number', 'event_type', 'turnover_type', 'attempt']

for i in range(0, len(col_list)):
    # Create a cursor object
    cur = conn.cursor()
    # SQL statement to alter the column data type
    alter_query = f"""ALTER TABLE public."OVERTIME_DETAILS_CURR" ADD COLUMN {col_list[i]} VARCHAR;"""
    # Execute the ALTER TABLE statement
    cur.execute(alter_query)
    # Commit the transaction
    conn.commit()
    # Close the cursor and connection
cur.close()
conn.close()

# %%
# Altering Database
# last alter -- Create OVERTIME_GAME_XREF_CURR
# As of 2/16/24

import psycopg2

conn = psycopg2.connect(
    dbname="RAD_DFS",
    user="postgres",
    password="Tigers11",
    host="localhost",
    port="5432"
)

# Column list
col_list = ['number']

for i in range(0, len(col_list)):
    # Create a cursor object
    cur = conn.cursor()
    # SQL statement to alter the column data type
    alter_query = f"""ALTER TABLE public."QUARTER_GAME_XREF_CURR" ADD COLUMN {col_list[i]} VARCHAR;"""
    # Execute the ALTER TABLE statement
    cur.execute(alter_query)
    # Commit the transaction
    conn.commit()
    # Close the cursor and connection
cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# DuplicateColumn                           Traceback (most recent call last)
# /Users/jorge/Documents/Documents - Jorge’s MacBook Pro/dev/python/data-sanitation/nba/prod/database_testing.ipynb Cell 12 line <cell line: 18>()
#      <a href='vscode-notebook-cell:/Users/jorge/Documents/Documents%20-%20Jorge%E2%80%99s%20MacBook%20Pro/dev/python/data-sanitation/nba/prod/database_testing.ipynb#X22sZmlsZQ%3D%3D?line=21'>22</a> alter_query = f"""ALTER TABLE public."QUARTER_GAME_XREF_CURR" ADD COLUMN {col_list[i]} VARCHAR;"""
#      <a href='vscode-notebook-cell:/Users/jorge/Documents/Documents%20-%20Jorge%E2%80%99s%20MacBook%20Pro/dev/python/data-sanitation/nba/prod/database_testing.ipynb#X22sZmlsZQ%3D%3D?line=22'>23</a> # Execute the ALTER TABLE statement
# ---> <a href='vscode-notebook-cell:/Users/jorge/Documents/Documents%20-%20Jorge%E2%80%99s%20MacBook%20Pro/dev/python/data-sanitation/nba/prod/database_testing.ipynb#X22sZmlsZQ%3D%3D?line=23'>24</a> cur.execute(alter_query)
#      <a href='vscode-notebook-cell:/Users/jorge/Documents/Documents%20-%20Jorge%E2%80%99s%20MacBook%20Pro/dev/python/data-sanitation/nba/prod/database_testing.ipynb#X22sZmlsZQ%3D%3D?line=24'>25</a> # Commit the transaction
#      <a href='vscode-notebook-cell:/Users/jorge/Documents/Documents%20-%20Jorge%E2%80%99s%20MacBook%20Pro/dev/python/data-sanitation/nba/prod/database_testing.ipynb#X22sZmlsZQ%3D%3D?line=25'>26</a> conn.commit()
#
# DuplicateColumn: column "number" of relation "QUARTER_GAME_XREF_CURR" already exists

# %%
# Altering Database

import psycopg2

conn = psycopg2.connect(
    dbname="RAD_DFS",
    user="postgres",
    password="Tigers11",
    host="localhost",
    port="5432"
)

# Create a cursor object
cur = conn.cursor()

# SQL statement to alter the column data type
alter_query = """ALTER TABLE public."QUARTER_GAME_XREF_CURR" ADD COLUMN id VARCHAR;"""

# Execute the ALTER TABLE statement
cur.execute(alter_query)

# Commit the transaction
conn.commit()

# Close the cursor and connection
cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# DuplicateColumn                           Traceback (most recent call last)
# /Users/jorge/Documents/Documents - Jorge’s MacBook Pro/dev/python/data-sanitation/nba/prod/database_testing.ipynb Cell 13 line <cell line: 20>()
#      <a href='vscode-notebook-cell:/Users/jorge/Documents/Documents%20-%20Jorge%E2%80%99s%20MacBook%20Pro/dev/python/data-sanitation/nba/prod/database_testing.ipynb#X14sZmlsZQ%3D%3D?line=16'>17</a> alter_query = """ALTER TABLE public."QUARTER_GAME_XREF_CURR" ADD COLUMN id VARCHAR;"""
#      <a href='vscode-notebook-cell:/Users/jorge/Documents/Documents%20-%20Jorge%E2%80%99s%20MacBook%20Pro/dev/python/data-sanitation/nba/prod/database_testing.ipynb#X14sZmlsZQ%3D%3D?line=18'>19</a> # Execute the ALTER TABLE statement
# ---> <a href='vscode-notebook-cell:/Users/jorge/Documents/Documents%20-%20Jorge%E2%80%99s%20MacBook%20Pro/dev/python/data-sanitation/nba/prod/database_testing.ipynb#X14sZmlsZQ%3D%3D?line=19'>20</a> cur.execute(alter_query)
#      <a href='vscode-notebook-cell:/Users/jorge/Documents/Documents%20-%20Jorge%E2%80%99s%20MacBook%20Pro/dev/python/data-sanitation/nba/prod/database_testing.ipynb#X14sZmlsZQ%3D%3D?line=21'>22</a> # Commit the transaction
#      <a href='vscode-notebook-cell:/Users/jorge/Documents/Documents%20-%20Jorge%E2%80%99s%20MacBook%20Pro/dev/python/data-sanitation/nba/prod/database_testing.ipynb#X14sZmlsZQ%3D%3D?line=22'>23</a> conn.commit()
#
# DuplicateColumn: column "id" of relation "QUARTER_GAME_XREF_CURR" already exists

# %%
import psycopg2

def exec_query(query):
    conn = psycopg2.connect(
        database="RAD_DFS", user="postgres", password="Tigers11", host="localhost", port="5432"
    )
    DF = pd.read_sql(query, conn)
    return DF

nba_test = exec_query('''SELECT * FROM public."GAME_DETAILS_CURR"''')

nba_test.head()
# Out:
# /Users/jorge/opt/anaconda3/envs/trading/lib/python3.10/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#                                      id  status coverage  \
# 0  0343c99e-bd5e-4887-aa21-94875b8dfba3  closed     full
# 1  b06ae4da-247e-4696-973a-7f1cbd813fec  closed     full
# 2  2ccf34f5-0139-4b4d-b84e-810af53ea9ba  closed     full
# 3  51285ac5-dfed-411a-bd1c-508a9626d1c3  closed     full
# 4  6731c976-ade6-4b15-8dea-d2c4ecf30bab  closed     full
#
#                    scheduled duration attendance lead_changes times_tied  \
# 0  2023-10-24T23:30:00+00:00     2:17      19842            1          1
# 1  2023-10-25T02:00:00+00:00     2:33      18064           12          9
# 2  2023-10-25T23:00:00+00:00     2:22      16129           15         10
# 3  2023-10-25T23:00:00+00:00     2:07      16004            5          3
# 4  2023-10-25T23:00:00+00:00     2:39      19812            4          6
#
#    clock quarter track_on_court   reference entry_mode              sr_id  \
# 0  00:00       4           true  0022300061  WEBSOCKET  sr:match:43065361
# 1  00:00       4           true  0022300062  WEBSOCKET  sr:match:43065363
# 2  00:00       4           true  0022300063  WEBSOCKET  sr:match:43065365
# 3  00:00       4           true  0022300064  WEBSOCKET  sr:match:43065367
# 4  00:00       4           true  0022300065  WEBSOCKET  sr:match:43065369
#
#   clock_decimal                             home_team  \
# 0         00:00  583ed102-fb46-11e1-82cb-f4ce4684ea4c
# 1         00:00  583ec825-fb46-11e1-82cb-f4ce4684ea4c
# 2         00:00  583ec97e-fb46-11e1-82cb-f4ce4684ea4c
# 3         00:00  583ec7cd-fb46-11e1-82cb-f4ce4684ea4c
# 4         00:00  583ec70e-fb46-11e1-82cb-f4ce4684ea4c
#
#                               away_team inseason_tournament title
# 0  583ecae2-fb46-11e1-82cb-f4ce4684ea4c                None  None
# 1  583ecfa8-fb46-11e1-82cb-f4ce4684ea4c                None  None
# 2  583ecb8f-fb46-11e1-82cb-f4ce4684ea4c                None  None
# 3  583ec8d4-fb46-11e1-82cb-f4ce4684ea4c                None  None
# 4  583eccfa-fb46-11e1-82cb-f4ce4684ea4c                None  None

# %%
nba_test['date_frmt'] = pd.to_datetime(nba_test['scheduled']).dt.strftime('%Y-%m-%d')

nba_test.head()
# Out:
#                                      id  status coverage  \
# 0  0343c99e-bd5e-4887-aa21-94875b8dfba3  closed     full
# 1  b06ae4da-247e-4696-973a-7f1cbd813fec  closed     full
# 2  2ccf34f5-0139-4b4d-b84e-810af53ea9ba  closed     full
# 3  51285ac5-dfed-411a-bd1c-508a9626d1c3  closed     full
# 4  6731c976-ade6-4b15-8dea-d2c4ecf30bab  closed     full
#
#                    scheduled duration attendance lead_changes times_tied  \
# 0  2023-10-24T23:30:00+00:00     2:17      19842            1          1
# 1  2023-10-25T02:00:00+00:00     2:33      18064           12          9
# 2  2023-10-25T23:00:00+00:00     2:22      16129           15         10
# 3  2023-10-25T23:00:00+00:00     2:07      16004            5          3
# 4  2023-10-25T23:00:00+00:00     2:39      19812            4          6
#
#    clock quarter track_on_court   reference entry_mode              sr_id  \
# 0  00:00       4           true  0022300061  WEBSOCKET  sr:match:43065361
# 1  00:00       4           true  0022300062  WEBSOCKET  sr:match:43065363
# 2  00:00       4           true  0022300063  WEBSOCKET  sr:match:43065365
# 3  00:00       4           true  0022300064  WEBSOCKET  sr:match:43065367
# 4  00:00       4           true  0022300065  WEBSOCKET  sr:match:43065369
#
#   clock_decimal                             home_team  \
# 0         00:00  583ed102-fb46-11e1-82cb-f4ce4684ea4c
# 1         00:00  583ec825-fb46-11e1-82cb-f4ce4684ea4c
# 2         00:00  583ec97e-fb46-11e1-82cb-f4ce4684ea4c
# 3         00:00  583ec7cd-fb46-11e1-82cb-f4ce4684ea4c
# 4         00:00  583ec70e-fb46-11e1-82cb-f4ce4684ea4c
#
#                               away_team inseason_tournament title   date_frmt
# 0  583ecae2-fb46-11e1-82cb-f4ce4684ea4c                None  None  2023-10-24
# 1  583ecfa8-fb46-11e1-82cb-f4ce4684ea4c                None  None  2023-10-25
# 2  583ecb8f-fb46-11e1-82cb-f4ce4684ea4c                None  None  2023-10-25
# 3  583ec8d4-fb46-11e1-82cb-f4ce4684ea4c                None  None  2023-10-25
# 4  583eccfa-fb46-11e1-82cb-f4ce4684ea4c                None  None  2023-10-25

# %%
feb_test = nba_test[nba_test['date_frmt']=='2024-02-05']

feb_test.head(10)
# Out:
#                                        id  status coverage  \
# 492  53ccfd01-23b0-47ff-b54f-cff31bd6ccce  closed     full
# 493  440d0420-270d-48e1-8392-541743a42ed7  closed     full
# 494  6d4f7b3a-0ae3-4b22-af2f-dd04fcefcad3  closed     full
# 495  9b117d60-3585-4211-a2b5-4458f353ebf3  closed     full
#
#                      scheduled duration attendance lead_changes times_tied  \
# 492  2024-02-05T01:30:00+00:00     2:00      19715            1          3
# 493  2024-02-05T01:00:00+00:00     2:15      18206            8          6
# 494  2024-02-05T00:00:00+00:00     2:33      17059            9         13
# 495  2024-02-05T00:00:00+00:00     2:15      18024            1          3
#
#      clock quarter track_on_court   reference entry_mode              sr_id  \
# 492  00:00       4           true  0022300712  WEBSOCKET  sr:match:43066669
# 493  00:00       4           true  0022300711  WEBSOCKET  sr:match:43066667
# 494  00:00       6           true  0022300710  WEBSOCKET  sr:match:43066665
# 495  00:00       4           true  0022300709  WEBSOCKET  sr:match:43066663
#
#     clock_decimal                             home_team  \
# 492         00:00  583ed102-fb46-11e1-82cb-f4ce4684ea4c
# 493         00:00  583ece50-fb46-11e1-82cb-f4ce4684ea4c
# 494         00:00  583ecfff-fb46-11e1-82cb-f4ce4684ea4c
# 495         00:00  583eca2f-fb46-11e1-82cb-f4ce4684ea4c
#
#                                 away_team inseason_tournament title  \
# 492  583ed056-fb46-11e1-82cb-f4ce4684ea4c                None  None
# 493  583ecefd-fb46-11e1-82cb-f4ce4684ea4c                None  None
# 494  583ecda6-fb46-11e1-82cb-f4ce4684ea4c                None  None
# 495  583ecb3a-fb46-11e1-82cb-f4ce4684ea4c                None  None
#
#       date_frmt
# 492  2024-02-05
# 493  2024-02-05
# 494  2024-02-05
# 495  2024-02-05
